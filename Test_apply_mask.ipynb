# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs

from src.preproces import *

# %% [markdown]
# # Import test file

# %%
file_handler = Handle_Files()
path_raw_data = '/nird/projects/NS9188K/bjornhs/ACCESS-ESM1-5/'

file_names = file_handler.get_all_netcdf_files_in_dir(path_raw_data)
test_file = file_handler.read_netcdf_to_xr(''.join([path_raw_data, file_names[2]]))
test_file
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 31411, bnds: 2, lon: 192, lat: 145)
# Coordinates:
#   * time       (time) datetime64[ns] 2015-01-01T12:00:00 ... 2100-12-31T12:00:00
#   * lon        (lon) float64 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#   * lat        (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lon_bnds   (lon, bnds) float64 ...
#     lat_bnds   (lat, bnds) float64 ...
#     tas        (time, lat, lon) float32 ...
# Attributes: (12/50)
#     CDI:                    Climate Data Interface version 1.9.9 (https://mpi...
#     source:                 ACCESS-ESM1.5 (2019): \naerosol: CLASSIC (v1.0)\n...
#     institution:            Commonwealth Scientific and Industrial Research O...
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     ...                     ...
#     variant_label:          r27i1p1f1
#     version:                v20210831
#     license:                CMIP6 model data produced by CSIRO is licensed un...
#     cmor_version:           3.4.0
#     tracking_id:            hdl:21.14100/cce6ed44-3b97-46f1-8aec-2621b4d67179
#     CDO:                    Climate Data Operators version 1.9.9 (https://mpi...

# %% [markdown]
# # Check compatability between mask and file.

# %%
def sort_condition(string):
    if 'land' in string:
        return True
    else:
        return False

path_raw_masks = '/nird/projects/NS9188K/bjornhs/ACCESS-ESM1-5/masks/'
file_handler.get_all_filenames_in_dir(path_raw_masks, sort_condition)
# Out:
# ['landfrac_ACCESS-ESM1-5.nc']

# %%
land_sea_mask = file_handler.read_netcdf_to_xr(''.join([path_raw_masks, 'landfrac_ACCESS-ESM1-5.nc']))
print(land_sea_mask)

preprocesser = Preprocess_Climate_Data()

preprocesser.check_mask_compatability(test_file, 'tas', land_sea_mask)
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 1, lon: 192, lat: 145)
# Coordinates:
#   * time      (time) object 0001-01-01 01:00:00
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 ... -7.5 -5.625 -3.75 -1.875
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
# Data variables:
#     landfrac  (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.10 (https://mpimet.mpg.d...
#     Conventions:  CF-1.4
#     history:      Wed Dec 06 14:14:19 2023: cdo remapcon,grid_ACCESS-ESM1-5.t...
#     CDO:          Climate Data Operators version 1.9.10 (https://mpimet.mpg.d...
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/coding/times.py:154: SerializationWarning: Ambiguous reference date string: 1-01-01 01:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-01-01 01:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/coding/times.py:724: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/core/indexing.py:557: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   array = array.get_duck_array()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 6
#       2 print(land_sea_mask)
#       4 preprocesser = Preprocess_Climate_Data()
# ----> 6 preprocesser.check_mask_compatability(test_file, 'tas', land_sea_mask)
#
# File ~/Masterthesis_S23/src/preproces.py:189, in Preprocess_Climate_Data.check_mask_compatability(self, xr_file, var_name, mask)
#     187     return True
#     188 else:
# --> 189     raise ValueError(f'Mask is not compatible with xr_file\n'
#     190                      f'lat compatibility: {lat_compatabiliy}\n'
#     191                      f'lon compatability: {lon_compatability}')
#
# ValueError: Mask is not compatible with xr_file
# lat compatibility: True
# lon compatability: False

# %% [markdown]
# The mask is not compatible, further investigation is needed to discover why lon is not compatible.

# %%
print(f'xr_file lon: \n {test_file.tas.lon}\n')
print(f'mask lon: \n{land_sea_mask.lon}')
# Out:
# xr_file lon:
#  <xarray.DataArray 'lon' (lon: 192)>
# array([  0.   ,   1.875,   3.75 ,   5.625,   7.5  ,   9.375,  11.25 ,  13.125,
#         15.   ,  16.875,  18.75 ,  20.625,  22.5  ,  24.375,  26.25 ,  28.125,
#         30.   ,  31.875,  33.75 ,  35.625,  37.5  ,  39.375,  41.25 ,  43.125,
#         45.   ,  46.875,  48.75 ,  50.625,  52.5  ,  54.375,  56.25 ,  58.125,
#         60.   ,  61.875,  63.75 ,  65.625,  67.5  ,  69.375,  71.25 ,  73.125,
#         75.   ,  76.875,  78.75 ,  80.625,  82.5  ,  84.375,  86.25 ,  88.125,
#        -110.625, -108.75 , -106.875, -105.   , -103.125, -101.25 ,  -99.375,
#         -97.5  ,  -95.625,  -93.75 ,  -91.875,  -90.   ,  -88.125,  -86.25 ,
#         -84.375,  -82.5  ,  -80.625,  -78.75 ,  -76.875,  -75.   ,  -73.125,
#         -71.25 ,  -69.375,  -67.5  ,  -65.625,  -63.75 ,  -61.875,  -60.   ,
#         -58.125,  -56.25 ,  -54.375,  -52.5  ,  -50.625,  -48.75 ,  -46.875,
#         -45.   ,  -43.125,  -41.25 ,  -39.375,  -37.5  ,  -35.625,  -33.75 ,
#         -31.875,  -30.   ,  -28.125,  -26.25 ,  -24.375,  -22.5  ,  -20.625,
#         -18.75 ,  -16.875,  -15.   ,  -13.125,  -11.25 ,   -9.375,   -7.5  ,
#          -5.625,   -3.75 ,   -1.875])
# Coordinates:
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... -7.5 -5.625 -3.75 -1.875
# Attributes:
#     standard_name:  longitude
#     long_name:      Longitude
#     units:          degrees_east
#     axis:           X

# %% [markdown]
# The mask uses negative values as degrees_east > 180 while the test_file uses 360 degree system. The number of lon is equal and thus also the resolution. I will let the mask inherite the lon from the test file and save the altered mask for future useage.

# %%
from cgi import test


land_sea_mask['lon'] = test_file.tas.lon

# rechek compatability, save if it is compatible
if preprocesser.check_mask_compatability(test_file, 'tas', land_sea_mask):
    file_handler.save_dataset_to_netcdf(land_sea_mask, 'landfrac_ACCESS-ESM1-5.nc', '/nird/home/johannef/Masterthesis_S23 DataFiles/masks')
# Out:
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/coding/times.py:154: SerializationWarning: Ambiguous reference date string: 1-01-01 01:00:00. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-01-01 01:00:00). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %% [markdown]
# # Apply land_sea mask to test_file

# %% [markdown]
#  To visualise the masking we use cartopy plotting.

# %%
path_altered_masks = '/nird/home/johannef/Masterthesis_S23 DataFiles/masks/'
land_sea_mask = file_handler.read_netcdf_to_xr(''.join([path_altered_masks, 'landfrac_ACCESS-ESM1-5.nc']))
# Out:
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/coding/times.py:724: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /nird/home/johannef/.conda/envs/msc_env/lib/python3.12/site-packages/xarray/core/indexing.py:557: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   array = array.get_duck_array()

# %%
def plot_on_globe(data,
                  center_lon=0, center_lat=20,
                  cmap='viridis',
                  title=None):
        """
        Plot data on a globe.

        Parameters:
        - data (xr.DataArray): The data to be plotted. Horizontal 2D data at a single time step.
        - center_lat (float): The latitude for the center of the plot.
        - center_lon (float): The longitude for the center of the plot.
        - title (str): The title of the plot.
        """
        p = data.plot(
                subplot_kws=dict(projection=ccrs.Orthographic(center_lon, center_lat), facecolor="gray"),
                transform=ccrs.PlateCarree()
        )
        p.axes.set_global()
        p.axes.coastlines()

        if title is None:
            title = "Globe plot"
        plt.title(title)

        plt.show()

# %%
land_sea_mask.landfrac.isel(time=0)
# Out:
# <xarray.DataArray 'landfrac' (lat: 145, lon: 192)>
# [27840 values with dtype=float32]
# Coordinates:
#     time     object 0001-01-01 01:00:00
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... -7.5 -5.625 -3.75 -1.875
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
# Attributes:
#     long_name:  0-1 from 5-min data
#     units:      0-1 from 5-min data

# %%
test_file.tas.isel(time=0)
# Out:
# <xarray.DataArray 'tas' (lat: 145, lon: 192)>
# [27840 values with dtype=float32]
# Coordinates:
#     time     datetime64[ns] 2015-01-01T12:00:00
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#     height   float64 ...
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     units:          K
#     comment:        near-surface (usually, 2 meter) air temperature
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2021-08-31T06:59:25Z altered by CMOR: Treated scalar dime...

# %%
plot_on_globe(test_file.tas.isel(time=0), title='Near surface air temperature for test_file at time step 0')
plot_on_globe(land_sea_mask.landfrac.isel(time=0), title='landfacture for land_sea_mask')
